# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

dataZ = pd.read_csv('result_benchZ.csv')
dataU = pd.read_csv('result_benchU.csv')
dataS = pd.read_csv('result_benchS.csv')
dataN = pd.read_csv('result_benchN.csv')
dataM = pd.read_csv('result_bench_monad.csv')
dataSO = pd.read_csv('result_benchSO.csv')

x= plt.boxplot((dataS, dataM, dataU, dataN, dataZ, dataSO))
